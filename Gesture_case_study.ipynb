# %% [markdown]
# <a href="https://colab.research.google.com/github/aditib7/Analytics-using-python-/blob/main/Gesture_case_study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Structure of Case Study Files:
#
# The data files that are given in this assignment are arranged as follows:
#
# There are 8 users. For each of the 8 users, there are 20 gestures. There are 20 files for gesture 1 itself and last 3 columns in each of the files correspond to x,y, and z coordinates. It is also given that each of these 8 users repeat 20 times each of their respective 20 gestures.
#
#
#
# Objective:
#
# The major objective of this assignment is to build a model for recognition of the gestures given in these files for each of the 8 users.
#
#
#
# Problems with the Accelerometer data:
#
# The accelerometer observations provided in the given case study is based on the data collected by the IMU or Inertial Measurement Unit Sensors. However, IMU sensor data is problematized by various experts as per our online research. One of the major IMU’s disadvantages is their accumulated error when integrating them with navigation equations alone in order to find the position. For example, double integration of the noisy acceleration leads to an inaccurate position solution that eventually results in a huge drift. Hence, many tracking navigation applications use additional sensors to mitigate these effects. Please refer to this link: https://towardsdatascience.com/what-is-imu-9565e55b44c.
#
# In addition, it is difficult to represent gestures in three dimensions as human gestures recorded by sensors contain considerable noise and are uncertain because of the possibility of orientations of gestures made by the users at different angles. The gesture recognition becomes all the more challenging because we have observed in the dataset that the length of each of the sequences of x,y, and z coordinates that together make a gesture vary widely even across repetitions of same gesture 20 times by the same user and also between users.
#
# It is also important to note that the dictionary of 12 hand gestures mentioned in the publication given along with the case study assignment question does not take into account whether those 12 gestures were performed by the users using their left hand or right hand. There are also issues in making more accurate gesture recognition as the gestures differ in shape and in the lengths of sequence of three-dimensional coordinates that constitute a gesture. For instance, two gestures in the dictionary of 12 hand gestures identified as 'S' and 'AS' in the given publication signify the trajectory when the hand is moved to the right and trajectory when the hand is moved to the left respectively. These two gestures, 'S' and 'AS' each represent a circular trajectory in three-dimensional space and hence the the starting points as well as the diameters of those circular trajectories can vary if performed by the same accelerometer user 20 times or performed by each of the 8 users. Researchers have failed to specify in the given publication what methods they have used to claim recognition of a complete gesture accurately with considerable possibility of different starting points and diameters of a circular trajectories in 'S' and 'AS' hand gestures.
#
# To summarise there are slew of major problems with accelerometer data when it comes to gesture recognition as investigated by the researchers in the given publication and the dataset that is given to us in the case study:
#
# 1. Different accelerometer sensor users can perform the same hand gesture differently.
#
# 2. Even the same accelerometer sensor user does not perform the same gesture in exactly in same manner every time he repeats a particular gesture.
#
# 3. We have observed by looking at the different lengths of sequences of movements that constitute a gesture that gesture recognition is also subject to the varied behavior of users in performing hand gestures as recorded by accelerometer data.
#
# 4. Most importantly, we are not aware of the source of the dataset that is given to us in the case study with respect to the device or sensor used to generate the particular accelerometer readings as we stated earlier that there are problems if IMU sensors are used in research study. We are also not aware whether the researchers, who generated the data given to us in the case study used a template of standard gestures to match the patterns and identify the occurrence of the 20 hand gestures in the dataset.
#
# 5. The given dataset only contains information about the coordinates without any information about the orientations in space as we pointed out earlier considering the users performing hand gestures at different angles.Furthermore, we don't know which of the hand gestures' three-dimensional coordinates were captured by the accelerometer using the left hand alone, right hand alone or both the hands of the users.
#
# 6. We also are not aware of the category of each of the 8 users, whose hand gestures were recorded in the dataset. For instance, if few of the users are kids, who performed hand gestures, then the researchers would keep the confidence level low and if other users, who performed the hand gestures are adults, then the researchers, who prepared the given dataset would keep a different confidence level. Here, 'Confidence' pertains to the probability of a particular hand movement or frame that is part of a particular gesture is the same as the one that was intended by the researchers to happen when they were conducting their research study.
#
# Our online research about recommended approach for gesture recognition in accelerometer data:
#
# We reviewed the research literature available online and concluded that the implementation of statistical approach, Hidden Markov Models is highly recommended and performed by many researchers for gesture recognition using accelerometer data and we have attached the links to refer to those articles. HMM(Hidden Markov Models) is recommended because it considers sequential data such as different frames or movements that together constitute a gesture and are claimed to perform better than most machine learning algorithms when it comes to gesture recognition from accelerometer data. Thus, Hidden Markov Models as a statistical approach is very relevant to the given case study. However, we were unable to retrieve a suitable Python code for Hidden Markov Models implementation based on our online investigation of research literature, official documentation of 'hmmlearn' Python package and other documents and support our analysis.
#
# Please read these research articles:
# 1. http://www.creativedistraction.com/demos/gesture-recognition-kinect-with-hidden-markov-models-hmms/
#
# 2. https://www.researchgate.net/publication/320627031_High_Five_Improving_Gesture_Recognition_by_Embracing_Uncertainty
#
# 3. https://hmmlearn.readthedocs.io/en/latest/
#
#
# Our inference regarding EDA or Data Visualization of Accelerometer Data:
#
# We have found based on our online research that it is difficult to represent three-dimensional accelerometer data visually as this kind of data is based not on the global coordinate system but on the sensor local coordinate system. For instance, researchers claimed that they developed in-house 3D-visualization tool along with application of AHRS (Attitude and Heading Reference System) algorithm to derive the orientation and visualize the data in a particular paper.
#
# Please read this article: https://www.mdpi.com/2504-3900/2/6/292/pdf

# %%
import os

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-00ef25da-3804-4f6b-9800-f7aee90c53f6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-00ef25da-3804-4f6b-9800-f7aee90c53f6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving gesture_old.csv.csv to gesture_old.csv.csv

# %%
# importing the packages

import pandas as pd

import numpy as np

# %%
# reading the file as a dataframe using pandas

gesture = pd.read_csv('gesture_old.csv.csv', index_col = 0)

gesture.head()

# removing the first 3 columns from gesture dataframe
# gesture_case = gesture.iloc[:, 3:]

# checking the first few observations of the dataframe

# gesture_case.head()
# Out:
#       TimeMillis        NanoTime      TimeStamp  ...         Y          Z  Label
# 0  1384186054309  78952598976553  1452892000000  ... -0.919373  10.113108      1
# 1  1384186054419  78952708778799  1453002000000  ... -0.919373   9.959879      1
# 2  1384186054531  78952821083487  1453112000000  ... -0.153229  10.726024      1
# 3  1384186054617  78952906563223  1453222000000  ...  3.371036  10.879252      1
# 4  1384186054728  78953017616690  1453332000000  ...  1.532289   9.193734      1
#
# [5 rows x 7 columns]

# %% [markdown]
# In order for us to create a label for each of the 20 gestures in the gesture_case dataframe, we first need to integrate the sequence of events that indicate a complete gesture in a single row to access the information about the gestures better.

# %%
# for 1st gesture in second user 

# accessing the 20 instances for each of the above 20 gestures using the text files stored for each of the
# gestures

list_1 = []
for k in range(1, 21, 1):
  if k < 10:
    gs1_inst_u2 = pd.read_table('0{}.txt'.format(k), delimiter = " ", names = ['TimeMillis', 'NanoTime', 'TimeStamp','X','Y','Z'])
    gs1_inst_u2.drop(['TimeMillis','NanoTime','TimeStamp'], axis = 1, inplace = True)
    list_1.append(len(gs1_inst_u2))
  if k >= 10:
    gs1_inst_u2 = pd.read_table('{}.txt'.format(k), delimiter = " ", names = ['TimeMillis', 'NanoTime', 'TimeStamp','X','Y','Z'])
    gs1_inst_u2.drop(['TimeMillis','NanoTime','TimeStamp'], axis = 1, inplace = True)
    list_1.append(len(gs1_inst_u2))


# now, based on the length of each of the text files, we will create a series with 'Instance', 'Gesture', and 'User' columns and then 
# add the series to gesture_case dataframe

# %%
list_06_1 = list_1

# %%
g4_u4 = pd.DataFrame([g1_u3_l + g2_u3_l + g3_u3_l + g4_u3_l])
         
g4_u4.to_csv('g4_u4.csv')

# %%
# checking the number for each of the 20 gestures in each of the files for user 2 to make a
# dataframe with the information about the length or number of sequence of events that 
# together made up a single gesture

g1_u3_l = []
g2_u3_l = []
g3_u3_l = []
g4_u3_l = []
g5_u3_l = []
g6_u3_l = []
g7_u3_l = []
g8_u3_l = []
g9_u3_l = []
g10_u3_l = []
g11_u3_l = []
g12_u3_l = []
g13_u3_l = []
g14_u3_l = []
g16_u3_l = []
g16_1_u3_l = []
g17_u3_l = []
g18_u3_l = []
g19_u3_l = []
g20_u3_l = []

# %%
# creating lists with instances details for gesture 1 of user 2

inst1_list8 = [1 for i in range(0, list_1[0], 1)]

inst2_list8 = [2 for i in range(0, list_1[1], 1)]

inst3_list8 = [3 for i in range(0, list_1[2], 1)]

inst4_list8 = [4 for i in range(0, list_1[3], 1)]

inst5_list8 = [5 for i in range(0, list_1[4], 1)]

inst6_list8 = [6 for i in range(0, list_1[5], 1)]

inst7_list8 = [7 for i in range(0, list_1[6], 1)]

inst8_list8 = [8 for i in range(0, list_1[7], 1)]

inst9_list8 = [9 for i in range(0, list_1[8], 1)]

inst10_list8 = [10 for i in range(0, list_1[9], 1)]

inst11_list8 = [11 for i in range(0, list_1[10], 1)]

inst12_list8 = [12 for i in range(0, list_1[11], 1)]

inst13_list8 = [13 for i in range(0, list_1[12], 1)]

inst14_list8 = [14 for i in range(0, list_1[13], 1)]

inst15_list8 = [15 for i in range(0, list_1[14], 1)]

inst16_list8 = [16 for i in range(0, list_1[15], 1)]

inst17_list8 = [17 for i in range(0, list_1[16], 1)]

inst18_list8 = [18 for i in range(0, list_1[17], 1)]

inst19_list8 = [19 for i in range(0, list_1[18], 1)]

inst20_list8 = [20 for i in range(0, list_1[19], 1)]

# %%
# creating integrated list of lists of each of the 20 instances in gesture 8 for user 1

u1_g8_list = inst1_list8 + inst2_list8 + inst3_list8 + inst4_list8 + inst5_list8 + inst6_list8 + inst7_list8 + inst8_list8 + inst9_list8 +\
inst10_list8 + inst11_list8 + inst12_list8 + inst13_list8 + inst14_list8 + inst15_list8 + inst16_list8 + inst17_list8 + \
inst18_list8 + inst19_list8 + inst20_list8

# %%
df_u8_g20 = pd.DataFrame(u1_g8_list)
df_u8_g20.to_csv('u8_g20_inst.csv')

# %%
csv_files = []
for v in range(1, 21, 1):
  extension = 'u8_g{}_inst.csv'.format(v)
  csv_files.append(extension)
file_1 = pd.read_csv(csv_files[0], index_col = 0)
file_2 = pd.read_csv(csv_files[1], index_col = 0)
file_3 = pd.read_csv(csv_files[2], index_col = 0)
file_4 = pd.read_csv(csv_files[3], index_col = 0)
file_5 = pd.read_csv(csv_files[4], index_col = 0)
file_6 = pd.read_csv(csv_files[5], index_col = 0)
file_7 = pd.read_csv(csv_files[6], index_col = 0)
file_8 = pd.read_csv(csv_files[7], index_col = 0)
file_9 = pd.read_csv(csv_files[8], index_col = 0) 
file_10 = pd.read_csv(csv_files[9], index_col = 0) 
file_11 = pd.read_csv(csv_files[10], index_col = 0)
file_12 = pd.read_csv(csv_files[11], index_col = 0)
file_13 = pd.read_csv(csv_files[12], index_col = 0)
file_14 = pd.read_csv(csv_files[13], index_col = 0)
file_15 = pd.read_csv(csv_files[14], index_col = 0)
file_16 = pd.read_csv(csv_files[15], index_col = 0)
file_17 = pd.read_csv(csv_files[16], index_col = 0)
file_18 = pd.read_csv(csv_files[17], index_col = 0)
file_19 = pd.read_csv(csv_files[18], index_col = 0)
file_20 = pd.read_csv(csv_files[19], index_col = 0)

files_gestures = [file_1, file_2, file_3, file_4, file_5, file_6, file_7, file_8,
                  file_9, file_10, file_11, file_12, file_13, file_14, file_15, 
                  file_16, file_17, file_18, file_19, file_20]

# %%
file_1.head()
# Out:
#    Instance  Gesture  User
# 0         1        1     2
# 1         1        1     2
# 2         1        1     2
# 3         1        1     2
# 4         1        1     2

# %%
list_ind = []
list_col = []
for i in range(1, 21, 1):
  col = 'U8-G{}'.format(i)
  ind = 'I-{}'.format(i)
  list_ind.append(ind)
  list_col.append(col)


inst_list = []
for y in range(0, len(files_gestures), 1):
  val_1 = files_gestures[y]
  val_list = []
  for i in range(1, 21, 1):
    val = list(val_1['Instance']).count(i)
    val_list.append(val)
  inst_list.append(val_list)

u8_instance_obs = pd.DataFrame(data = inst_list, index = list_ind, columns = list_col)

u8_instance_obs
# Out:
#       U8-G1  U8-G2  U8-G3  U8-G4  U8-G5  ...  U8-G16  U8-G17  U8-G18  U8-G19  U8-G20
# I-1      17     17     17     17     17  ...      17      18      17      17      16
# I-2      16     15     16     15     14  ...      12      13      14      14      13
# I-3      18     13     13     13     14  ...      13      13      14      15      14
# I-4      14     14     13     13     12  ...      13      13      13      12      12
# I-5      17     18     18     19     19  ...      19      20      21      20      19
# I-6      19     20     19     19     20  ...      19      18      19      19      19
# I-7      24     24     25     23     26  ...      22      21      23      21      22
# I-8      24     21     24     24     24  ...      24      23      24      26      23
# I-9      18     17     17     17     18  ...      16      18      17      18      16
# I-10     17     16     16     16     15  ...      14      14      15      15      14
# ...

# %%
u8_instance_obs.to_csv('u8_instance_obs.csv')

# %% [markdown]
# On the basis of above dataframe, we will check the values that are there in most of the gestures for user 1 and compare these with the rest of the users to create the final dataframe as we need to have uniform numbers of both the columns and rows in the data used for analysis. In addition, we have to make sure that we are taking one complete event or instance of each of the gestures to incorporate complete information about the gestures in data analysis.

# %%
u3_instances_obs.to_csv('u3_instances_obs.csv')

# %% [markdown]
# The data files that are given in this assignment are arranged as follows:
#
# There are 8 users. For each of the 8 users, there are 20 gestures. There are 20 files for gesture 1 itself and last 3 columns in each of the files correspond to x,y, and z coordinates. The major objective of this assignment is to build a model for recognition of the gestures given in these files for each of the 8 users.
